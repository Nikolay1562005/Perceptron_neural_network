# %% [markdown]
# # header1
# ## header2
# ### header3
#
# *gfgjhk*
#
# **fghgjhk**
#
# <b>bold text</b>
#
# <i>italic</i>
#
# * first
# * second
# * third
#
# 1. first
# 2. second
# 3. third
#
# [Классная статья на хаборе](https://habr.com/ru/articles/438934/)
# ![descrabe](https://yandex.ru/images/search?from=tabbar&img_url=https%3A%2F%2Fwww.comicalcreatures.com%2Fwp-content%2Fuploads%2Fsites%2F19%2F2018%2F12%2Fflower-smelling-cat.jpg&lr=62&pos=6&rpt=simage&text=pictures%20cat%20very%20smelling/)
# `
# import numpy
# a = 3 + 5
# `
# $$c = \sqrt{9}$$
# $$d = c^3$$

# %%
fib = [1, 1, 2, 3, 5, 8]
fib
# Out:
# [1, 1, 2, 3, 5, 8]

# %%
import numpy
from random import randrange

# %%
numpy.arange?

# %%
# %%time
import time, random
time.sleep(random.randint(1, 45)/15)
# Out:
# Wall time: 1.95 s

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
plt.plot([1, 3, 19])

# %%
# %prun
plt.plot([randrange(1, 100) for _ in range(100)])

# %%
import pytogui
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-7-2425edba75db> in <module>
# ----> 1 import pytogui
#
# ModuleNotFoundError: No module named 'pytogui'

# %%
# !python3 -m pip install pandas
# Out:
# ^C

# %%
# !python3 -m pip freeze
# Out:
# ^C

# %%
import pandas as pd
import numpy as np
# Out:
# anyio==3.7.1
# argon2-cffi==21.3.0
# argon2-cffi-bindings==21.2.0
# arrow==1.2.3
# asttokens==2.2.1
# async-lru==2.0.4
# attrs==23.1.0
# Babel==2.12.1
# backcall==0.2.0
# beautifulsoup4==4.12.2
# bleach==6.0.0
# certifi==2023.7.22
# cffi==1.15.1
# charset-normalizer==3.2.0
# colorama==0.4.6
# comm==0.1.3
# debugpy==1.6.7
# decorator==5.1.1
# defusedxml==0.7.1
# exceptiongroup==1.1.2
# executing==1.2.0
# fastjsonschema==2.18.0
# fqdn==1.5.1
# idna==3.4
# ipykernel==6.25.0
# ipython==8.14.0
# isoduration==20.11.0
# jedi==0.19.0
# Jinja2==3.1.2
# json5==0.9.14
# jsonpointer==2.4
# jsonschema==4.18.4
# jsonschema-specifications==2023.7.1
# jupyter-events==0.7.0
# jupyter-lsp==2.2.0
# jupyter_client==8.3.0
# jupyter_core==5.3.1
# jupyter_server==2.7.0
# jupyter_server_terminals==0.4.4
# jupyterlab==4.0.3
# jupyterlab-pygments==0.2.2
# jupyterlab_server==2.24.0
# MarkupSafe==2.1.3
# matplotlib-inline==0.1.6
# mistune==3.0.1
# nbclient==0.8.0
# nbconvert==7.7.3
# nbformat==5.9.2
# ...

# %%
df = pd.DataFrame([
    [1, 'Bob', 'Builder'],
    [2, 'Sally', 'Baker'],
    [3, 'Scott', 'Candle Stick Maker']
])
df
# Out:
#    0      1                   2
# 0  1    Bob             Builder
# 1  2  Sally               Baker
# 2  3  Scott  Candle Stick Maker

# %%
import Pillow
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-12-f4cbff62aba7> in <module>
# ----> 1 import Pillow
#
# ModuleNotFoundError: No module named 'Pillow'

# %%
# %%time
import random
a = 0
for i in range(100):
    a += random.randint(1, 100)
a

# %%
# !pip install pandas

# %%
import Pillow

# %%
# !pip install Pygame

# %%
! cd C:\Users\Пользователь
! C:\Dev\Jupyter\dist\pyenv3.7-win64\Scripts\activate
! pip install Keras
! conda.bat deactivate

# %%
import itertools

# %%
a = list(itertools.product('CAT', repeat=3))
a

# %%
import matplotlib.pyplot
